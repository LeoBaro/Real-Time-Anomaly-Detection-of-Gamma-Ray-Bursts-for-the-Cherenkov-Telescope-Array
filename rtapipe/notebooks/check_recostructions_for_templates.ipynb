# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import yaml
import pandas as pd
import numpy as np
from functools import partial
import multiprocessing
import tensorflow as tf
from pathlib import Path
from time import strftime
from shutil import rmtree
import matplotlib.pyplot as plt
from tqdm import tqdm
import matplotlib
matplotlib.use("TKAgg", force=True)
# %matplotlib inline
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from rtapipe.lib.utils.misc import dotdict
from rtapipe.lib.dataset.data_manager import DataManager
from rtapipe.lib.datasource.Photometry3 import OnlinePhotometry, SimulationParams
from rtapipe.lib.plotting.plotting import plot_sequences
from rtapipe.lib.models.anomaly_detector_builder import AnomalyDetectorBuilder
from rtapipe.lib.evaluation.pval import get_pval_table, get_threshold_for_sigma
from rtapipe.lib.standardanalysis.li_ma import LiMa
from rtapipe.lib.evaluation.pval import get_pval_table, get_threshold_for_sigma, get_sigma_from_pvalue, get_sigma_for_ts_array, get_sigma_from_ts

# %% [markdown]
# # Loading the models

# %%
def load_model(model_id):
    with open("./trained_models.yaml", "r") as f:
        try:
            configs = yaml.safe_load(f)
        except yaml.YAMLError as exc:
            print(exc)
    model_config = [c for c in configs["models"] if c["id"] == model_id]
    model_config = dotdict(model_config.pop())
    model_config.ad = AnomalyDetectorBuilder.getAnomalyDetector(name=model_config.name, timesteps=model_config.timesteps, nfeatures=model_config.nfeatures, load_model="True", training_epoch_dir=model_config.path, training=False)
    model_config.pvalue_table = get_pval_table(model_config.pval_path) 
    return model_config

# %%
#model_config_cnn = load_model(0)
#model_config_cnn

# %%
model_config_rnn = load_model(1)
model_config_rnn
# Out:
# AnomalyDetector_rnn_l2_u32 - input shape: (5,3)
# {'id': 1,
#  'patience': 5,
#  'integrationtime': 5,
#  'timesteps': 5,
#  'nfeatures': 3,
#  'scaler': 'minmax',
#  'name': 'AnomalyDetector_rnn_l2_u32',
#  'path': '/data01/homes/baroncelli/phd/rtapipe/notebooks/run_20221116-101109_mr_patience_5/model_AnomalyDetector_rnn_l2_u32_dataset_train_itime_5_a_tsl_5_nbins_3_tsl_3600/epochs/epoch_10',
#  'epoch': 10,
#  'pval_path': '/data01/homes/baroncelli/phd/rtapipe/notebooks/run_20221116-101109_mr_patience_5/model_AnomalyDetector_rnn_l2_u32_dataset_train_itime_5_a_tsl_5_nbins_3_tsl_3600/epochs/epoch_10/pvalues/pval_20221121-132236/pvalue_bins_100_0.numpy.txt',
#  'scaler_path': '/data01/homes/baroncelli/phd/rtapipe/notebooks/run_20221116-101109_mr_patience_5/model_AnomalyDetector_rnn_l2_u32_dataset_train_itime_5_a_tsl_5_nbins_3_tsl_3600/fitted_scaler.pickle',
#  'ad': <rtapipe.lib.models.anomaly_detector_rnn.AnomalyDetector_rnn_l2_u32 at 0x2af318d23f10>,
#  'pvalue_table':     threshold  threshold_err        pvalue    pvalue_err  sigma
#  0    0.000227       0.000013  1.416930e-01  1.254772e-04  1.073
#  1    0.000253       0.000013  9.859137e-02  1.046671e-04  1.290
#  2    0.000279       0.000013  6.802256e-02  8.693953e-05  1.491
#  3    0.000305       0.000013  4.666059e-02  7.200554e-05  1.678
#  4    0.000331       0.000013  3.223601e-02  5.984963e-05  1.849
#  ..        ...            ...           ...           ...    ...
#  87   0.002495       0.000013  1.111173e-07  1.111173e-07  5.180
#  88   0.002521       0.000013  1.111173e-07  1.111173e-07  5.180
#  89   0.002547       0.000013  1.111173e-07  1.111173e-07  5.180
#  90   0.002574       0.000013  1.111173e-07  1.111173e-07  5.180
#  91   0.002600       0.000013  1.111173e-07  1.111173e-07  5.180
#
#  [92 rows x 5 columns]}

# %% [markdown]
# # Loading the test dataset

# %%
output_dir = "./logs/check_recostructions_for_templates_out"

# %%
features_names = ["EB_0.04-0.117","EB_2-0.117-0.342","EB_0.342-1"]

# %%
data_manager = DataManager(output_dir)

# %%
dataset_id="test_itime_5_c_tsl_5_nbins_3"

# %%
dataset_folder = "/data01/homes/baroncelli/phd/rtapipe/scripts/ml/dataset_generation/test/itime_5_h/fits_data"
fits_files = DataManager.load_fits_data(dataset_folder, limit=500)
test_set_size = len(fits_files)
# Out:
# Loaded 419 files

# %%
sim_params = SimulationParams(runid=None, onset=250, emin=0.04, emax=1, tmin=0, tobs=500, offset=0.5, irf="North_z40_5h_LST", roi=2.5, caldb="prod5-v0.1", simtype="grb")
multiple_templates = True
add_target_region = True
integration_time = 5
number_of_energy_bins = 3
tsl = 100
threads = 30
normalize = True
#data_manager.transform_to_timeseries(fits_files, sim_params, add_target_region, integration_time=integration_time, number_of_energy_bins=number_of_energy_bins, tsl=tsl, normalize=normalize, threads=threads, multiple_templates=multiple_templates)
data_manager.load_saved_data(5, 100)
# Out:
# Loading cached data from run0002_ID000044_it_5_tsl_100.npy
# Loading cached data from run0005_ID000225_it_5_tsl_100.npy
# Loading cached data from run0009_ID000191_it_5_tsl_100.npy
# Loading cached data from run0011_ID000139_it_5_tsl_100.npy
# Loading cached data from run0013_ID000321_it_5_tsl_100.npy
# Loading cached data from run0016_ID000340_it_5_tsl_100.npy
# Loading cached data from run0017_ID000132_it_5_tsl_100.npy
# Loading cached data from run0017_ID000261_it_5_tsl_100.npy
# Loading cached data from run0017_ID000302_it_5_tsl_100.npy
# Loading cached data from run0019_ID000070_it_5_tsl_100.npy
# Loading cached data from run0019_ID000268_it_5_tsl_100.npy
# Loading cached data from run0019_ID000338_it_5_tsl_100.npy
# Loading cached data from run0021_ID000373_it_5_tsl_100.npy
# Loading cached data from run0023_ID000267_it_5_tsl_100.npy
# Loading cached data from run0025_ID000471_it_5_tsl_100.npy
# Loading cached data from run0026_ID000127_it_5_tsl_100.npy
# Loading cached data from run0027_ID000288_it_5_tsl_100.npy
# Loading cached data from run0029_ID000397_it_5_tsl_100.npy
# Loading cached data from run0029_ID000446_it_5_tsl_100.npy
# Loading cached data from run0032_ID000190_it_5_tsl_100.npy
# Loading cached data from run0036_ID000168_it_5_tsl_100.npy
# Loading cached data from run0037_ID000283_it_5_tsl_100.npy
# Loading cached data from run0038_ID000228_it_5_tsl_100.npy
# Loading cached data from run0039_ID000031_it_5_tsl_100.npy
# Loading cached data from run0043_ID000231_it_5_tsl_100.npy
# Loading cached data from run0043_ID000324_it_5_tsl_100.npy
# Loading cached data from run0043_ID000460_it_5_tsl_100.npy
# Loading cached data from run0045_ID000095_it_5_tsl_100.npy
# Loading cached data from run0046_ID000029_it_5_tsl_100.npy
# Loading cached data from run0046_ID000300_it_5_tsl_100.npy
# Loading cached data from run0048_ID000219_it_5_tsl_100.npy
# Loading cached data from run0048_ID000465_it_5_tsl_100.npy
# Loading cached data from run0050_ID000319_it_5_tsl_100.npy
# Loading cached data from run0051_ID000166_it_5_tsl_100.npy
# Loading cached data from run0051_ID000434_it_5_tsl_100.npy
# Loading cached data from run0053_ID000030_it_5_tsl_100.npy
# Loading cached data from run0055_ID000128_it_5_tsl_100.npy
# Loading cached data from run0058_ID000423_it_5_tsl_100.npy
# Loading cached data from run0066_ID000041_it_5_tsl_100.npy
# Loading cached data from run0066_ID000123_it_5_tsl_100.npy
# Loading cached data from run0067_ID000038_it_5_tsl_100.npy
# Loading cached data from run0067_ID000395_it_5_tsl_100.npy
# Loading cached data from run0074_ID000249_it_5_tsl_100.npy
# Loading cached data from run0076_ID000465_it_5_tsl_100.npy
# Loading cached data from run0077_ID000381_it_5_tsl_100.npy
# Loading cached data from run0079_ID000181_it_5_tsl_100.npy
# Loading cached data from run0079_ID000383_it_5_tsl_100.npy
# Loading cached data from run0080_ID000283_it_5_tsl_100.npy
# Loading cached data from run0087_ID000156_it_5_tsl_100.npy
# Loading cached data from run0091_ID000232_it_5_tsl_100.npy
# Loading cached data from run0096_ID000038_it_5_tsl_100.npy
# Loading cached data from run0099_ID000496_it_5_tsl_100.npy
# Loading cached data from run0101_ID000172_it_5_tsl_100.npy
# Loading cached data from run0103_ID000247_it_5_tsl_100.npy
# Loading cached data from run0106_ID000232_it_5_tsl_100.npy
# Loading cached data from run0108_ID000020_it_5_tsl_100.npy
# Loading cached data from run0109_ID000136_it_5_tsl_100.npy
# Loading cached data from run0111_ID000027_it_5_tsl_100.npy
# Loading cached data from run0111_ID000118_it_5_tsl_100.npy
# Loading cached data from run0113_ID000112_it_5_tsl_100.npy
# Loading cached data from run0114_ID000299_it_5_tsl_100.npy
# Loading cached data from run0115_ID000189_it_5_tsl_100.npy
# Loading cached data from run0117_ID000327_it_5_tsl_100.npy
# Loading cached data from run0118_ID000382_it_5_tsl_100.npy
# Loading cached data from run0118_ID000393_it_5_tsl_100.npy
# Loading cached data from run0121_ID000156_it_5_tsl_100.npy
# Loading cached data from run0121_ID000209_it_5_tsl_100.npy
# Loading cached data from run0122_ID000021_it_5_tsl_100.npy
# Loading cached data from run0124_ID000071_it_5_tsl_100.npy
# Loading cached data from run0125_ID000077_it_5_tsl_100.npy
# Loading cached data from run0126_ID000344_it_5_tsl_100.npy
# Loading cached data from run0130_ID000461_it_5_tsl_100.npy
# Loading cached data from run0131_ID000391_it_5_tsl_100.npy
# Loading cached data from run0132_ID000380_it_5_tsl_100.npy
# Loading cached data from run0138_ID000218_it_5_tsl_100.npy
# Loading cached data from run0142_ID000123_it_5_tsl_100.npy
# Loading cached data from run0146_ID000301_it_5_tsl_100.npy
# Loading cached data from run0147_ID000002_it_5_tsl_100.npy
# Loading cached data from run0150_ID000189_it_5_tsl_100.npy
# Loading cached data from run0151_ID000312_it_5_tsl_100.npy
# Loading cached data from run0154_ID000068_it_5_tsl_100.npy
# Loading cached data from run0155_ID000328_it_5_tsl_100.npy
# Loading cached data from run0156_ID000028_it_5_tsl_100.npy
# Loading cached data from run0157_ID000407_it_5_tsl_100.npy
# Loading cached data from run0158_ID000220_it_5_tsl_100.npy
# Loading cached data from run0158_ID000313_it_5_tsl_100.npy
# Loading cached data from run0158_ID000359_it_5_tsl_100.npy
# Loading cached data from run0159_ID000035_it_5_tsl_100.npy
# Loading cached data from run0160_ID000149_it_5_tsl_100.npy
# Loading cached data from run0162_ID000268_it_5_tsl_100.npy
# Loading cached data from run0163_ID000414_it_5_tsl_100.npy
# Loading cached data from run0167_ID000041_it_5_tsl_100.npy
# Loading cached data from run0170_ID000124_it_5_tsl_100.npy
# Loading cached data from run0170_ID000218_it_5_tsl_100.npy
# Loading cached data from run0170_ID000400_it_5_tsl_100.npy
# Loading cached data from run0170_ID000418_it_5_tsl_100.npy
# Loading cached data from run0173_ID000131_it_5_tsl_100.npy
# Loading cached data from run0175_ID000139_it_5_tsl_100.npy
# Loading cached data from run0175_ID000300_it_5_tsl_100.npy
# Loading cached data from run0176_ID000218_it_5_tsl_100.npy
# Loading cached data from run0176_ID000272_it_5_tsl_100.npy
# Loading cached data from run0176_ID000473_it_5_tsl_100.npy
# Loading cached data from run0177_ID000070_it_5_tsl_100.npy
# Loading cached data from run0180_ID000255_it_5_tsl_100.npy
# Loading cached data from run0181_ID000296_it_5_tsl_100.npy
# Loading cached data from run0182_ID000054_it_5_tsl_100.npy
# Loading cached data from run0183_ID000331_it_5_tsl_100.npy
# Loading cached data from run0187_ID000435_it_5_tsl_100.npy
# Loading cached data from run0189_ID000293_it_5_tsl_100.npy
# Loading cached data from run0191_ID000005_it_5_tsl_100.npy
# Loading cached data from run0191_ID000229_it_5_tsl_100.npy
# Loading cached data from run0192_ID000017_it_5_tsl_100.npy
# Loading cached data from run0192_ID000068_it_5_tsl_100.npy
# Loading cached data from run0193_ID000013_it_5_tsl_100.npy
# Loading cached data from run0193_ID000134_it_5_tsl_100.npy
# Loading cached data from run0195_ID000111_it_5_tsl_100.npy
# Loading cached data from run0197_ID000145_it_5_tsl_100.npy
# Loading cached data from run0199_ID000215_it_5_tsl_100.npy
# Loading cached data from run0199_ID000278_it_5_tsl_100.npy
# Loading cached data from run0202_ID000245_it_5_tsl_100.npy
# Loading cached data from run0204_ID000284_it_5_tsl_100.npy
# Loading cached data from run0207_ID000154_it_5_tsl_100.npy
# Loading cached data from run0209_ID000300_it_5_tsl_100.npy
# Loading cached data from run0210_ID000016_it_5_tsl_100.npy
# Loading cached data from run0210_ID000040_it_5_tsl_100.npy
# Loading cached data from run0210_ID000082_it_5_tsl_100.npy
# Loading cached data from run0210_ID000221_it_5_tsl_100.npy
# Loading cached data from run0211_ID000312_it_5_tsl_100.npy
# Loading cached data from run0211_ID000462_it_5_tsl_100.npy
# Loading cached data from run0214_ID000101_it_5_tsl_100.npy
# Loading cached data from run0216_ID000185_it_5_tsl_100.npy
# Loading cached data from run0216_ID000333_it_5_tsl_100.npy
# Loading cached data from run0218_ID000245_it_5_tsl_100.npy
# Loading cached data from run0219_ID000029_it_5_tsl_100.npy
# Loading cached data from run0221_ID000122_it_5_tsl_100.npy
# Loading cached data from run0221_ID000373_it_5_tsl_100.npy
# Loading cached data from run0222_ID000126_it_5_tsl_100.npy
# Loading cached data from run0222_ID000318_it_5_tsl_100.npy
# Loading cached data from run0226_ID000257_it_5_tsl_100.npy
# Loading cached data from run0226_ID000442_it_5_tsl_100.npy
# Loading cached data from run0228_ID000404_it_5_tsl_100.npy
# Loading cached data from run0231_ID000152_it_5_tsl_100.npy
# Loading cached data from run0231_ID000320_it_5_tsl_100.npy
# Loading cached data from run0233_ID000376_it_5_tsl_100.npy
# Loading cached data from run0236_ID000181_it_5_tsl_100.npy
# Loading cached data from run0240_ID000371_it_5_tsl_100.npy
# Loading cached data from run0240_ID000477_it_5_tsl_100.npy
# Loading cached data from run0242_ID000066_it_5_tsl_100.npy
# Loading cached data from run0242_ID000208_it_5_tsl_100.npy
# Loading cached data from run0245_ID000236_it_5_tsl_100.npy
# Loading cached data from run0250_ID000440_it_5_tsl_100.npy
# Loading cached data from run0251_ID000377_it_5_tsl_100.npy
# Loading cached data from run0252_ID000066_it_5_tsl_100.npy
# Loading cached data from run0254_ID000090_it_5_tsl_100.npy
# Loading cached data from run0254_ID000456_it_5_tsl_100.npy
# Loading cached data from run0254_ID000470_it_5_tsl_100.npy
# Loading cached data from run0256_ID000112_it_5_tsl_100.npy
# Loading cached data from run0258_ID000139_it_5_tsl_100.npy
# Loading cached data from run0258_ID000165_it_5_tsl_100.npy
# Loading cached data from run0263_ID000260_it_5_tsl_100.npy
# Loading cached data from run0266_ID000397_it_5_tsl_100.npy
# Loading cached data from run0270_ID000260_it_5_tsl_100.npy
# Loading cached data from run0270_ID000262_it_5_tsl_100.npy
# Loading cached data from run0271_ID000336_it_5_tsl_100.npy
# Loading cached data from run0276_ID000003_it_5_tsl_100.npy
# Loading cached data from run0276_ID000042_it_5_tsl_100.npy
# Loading cached data from run0278_ID000111_it_5_tsl_100.npy
# Loading cached data from run0278_ID000152_it_5_tsl_100.npy
# Loading cached data from run0279_ID000405_it_5_tsl_100.npy
# Loading cached data from run0280_ID000101_it_5_tsl_100.npy
# Loading cached data from run0283_ID000065_it_5_tsl_100.npy
# Loading cached data from run0284_ID000362_it_5_tsl_100.npy
# Loading cached data from run0285_ID000014_it_5_tsl_100.npy
# Loading cached data from run0286_ID000021_it_5_tsl_100.npy
# Loading cached data from run0286_ID000099_it_5_tsl_100.npy
# Loading cached data from run0286_ID000206_it_5_tsl_100.npy
# Loading cached data from run0290_ID000056_it_5_tsl_100.npy
# Loading cached data from run0291_ID000001_it_5_tsl_100.npy
# Loading cached data from run0291_ID000193_it_5_tsl_100.npy
# Loading cached data from run0292_ID000156_it_5_tsl_100.npy
# Loading cached data from run0294_ID000203_it_5_tsl_100.npy
# Loading cached data from run0298_ID000339_it_5_tsl_100.npy
# Loading cached data from run0301_ID000376_it_5_tsl_100.npy
# Loading cached data from run0302_ID000382_it_5_tsl_100.npy
# Loading cached data from run0309_ID000061_it_5_tsl_100.npy
# Loading cached data from run0314_ID000223_it_5_tsl_100.npy
# Loading cached data from run0315_ID000129_it_5_tsl_100.npy
# Loading cached data from run0317_ID000219_it_5_tsl_100.npy
# Loading cached data from run0318_ID000143_it_5_tsl_100.npy
# Loading cached data from run0321_ID000159_it_5_tsl_100.npy
# Loading cached data from run0323_ID000052_it_5_tsl_100.npy
# Loading cached data from run0325_ID000165_it_5_tsl_100.npy
# Loading cached data from run0339_ID000132_it_5_tsl_100.npy
# Loading cached data from run0339_ID000241_it_5_tsl_100.npy
# Loading cached data from run0340_ID000060_it_5_tsl_100.npy
# Loading cached data from run0340_ID000247_it_5_tsl_100.npy
# Loading cached data from run0341_ID000126_it_5_tsl_100.npy
# Loading cached data from run0342_ID000307_it_5_tsl_100.npy
# Loading cached data from run0343_ID000134_it_5_tsl_100.npy
# Loading cached data from run0344_ID000129_it_5_tsl_100.npy
# Loading cached data from run0347_ID000361_it_5_tsl_100.npy
# Loading cached data from run0349_ID000154_it_5_tsl_100.npy
# Loading cached data from run0350_ID000115_it_5_tsl_100.npy
# Loading cached data from run0350_ID000189_it_5_tsl_100.npy
# Loading cached data from run0352_ID000021_it_5_tsl_100.npy
# Loading cached data from run0352_ID000076_it_5_tsl_100.npy
# Loading cached data from run0352_ID000163_it_5_tsl_100.npy
# Loading cached data from run0354_ID000089_it_5_tsl_100.npy
# Loading cached data from run0355_ID000275_it_5_tsl_100.npy
# Loading cached data from run0356_ID000097_it_5_tsl_100.npy
# Loading cached data from run0358_ID000063_it_5_tsl_100.npy
# Loading cached data from run0361_ID000216_it_5_tsl_100.npy
# Loading cached data from run0363_ID000327_it_5_tsl_100.npy
# Loading cached data from run0368_ID000124_it_5_tsl_100.npy
# Loading cached data from run0369_ID000392_it_5_tsl_100.npy
# Loading cached data from run0370_ID000146_it_5_tsl_100.npy
# Loading cached data from run0374_ID000020_it_5_tsl_100.npy
# Loading cached data from run0378_ID000129_it_5_tsl_100.npy
# Loading cached data from run0382_ID000397_it_5_tsl_100.npy
# Loading cached data from run0383_ID000191_it_5_tsl_100.npy
# Loading cached data from run0384_ID000378_it_5_tsl_100.npy
# Loading cached data from run0385_ID000009_it_5_tsl_100.npy
# Loading cached data from run0389_ID000142_it_5_tsl_100.npy
# Loading cached data from run0389_ID000280_it_5_tsl_100.npy
# Loading cached data from run0395_ID000138_it_5_tsl_100.npy
# Loading cached data from run0396_ID000359_it_5_tsl_100.npy
# Loading cached data from run0398_ID000008_it_5_tsl_100.npy
# Loading cached data from run0401_ID000227_it_5_tsl_100.npy
# Loading cached data from run0403_ID000285_it_5_tsl_100.npy
# Loading cached data from run0406_ID000126_it_5_tsl_100.npy
# Loading cached data from run0407_ID000101_it_5_tsl_100.npy
# Loading cached data from run0410_ID000250_it_5_tsl_100.npy
# Loading cached data from run0410_ID000273_it_5_tsl_100.npy
# Loading cached data from run0410_ID000425_it_5_tsl_100.npy
# Loading cached data from run0415_ID000055_it_5_tsl_100.npy
# Loading cached data from run0419_ID000300_it_5_tsl_100.npy
# Loading cached data from run0420_ID000152_it_5_tsl_100.npy
# Loading cached data from run0421_ID000208_it_5_tsl_100.npy
# Loading cached data from run0421_ID000212_it_5_tsl_100.npy
# Loading cached data from run0421_ID000383_it_5_tsl_100.npy
# Loading cached data from run0423_ID000024_it_5_tsl_100.npy
# Loading cached data from run0428_ID000157_it_5_tsl_100.npy
# Loading cached data from run0429_ID000078_it_5_tsl_100.npy
# Loading cached data from run0431_ID000202_it_5_tsl_100.npy
# Loading cached data from run0434_ID000189_it_5_tsl_100.npy
# Loading cached data from run0436_ID000045_it_5_tsl_100.npy
# Loading cached data from run0444_ID000110_it_5_tsl_100.npy
# Loading cached data from run0445_ID000162_it_5_tsl_100.npy
# Loading cached data from run0446_ID000308_it_5_tsl_100.npy
# Loading cached data from run0452_ID000030_it_5_tsl_100.npy
# Loading cached data from run0453_ID000359_it_5_tsl_100.npy
# Loading cached data from run0454_ID000028_it_5_tsl_100.npy
# Loading cached data from run0457_ID000240_it_5_tsl_100.npy
# Loading cached data from run0459_ID000351_it_5_tsl_100.npy
# Loading cached data from run0460_ID000344_it_5_tsl_100.npy
# Loading cached data from run0461_ID000109_it_5_tsl_100.npy
# Loading cached data from run0467_ID000192_it_5_tsl_100.npy
# Loading cached data from run0468_ID000072_it_5_tsl_100.npy
# Loading cached data from run0473_ID000322_it_5_tsl_100.npy
# Loading cached data from run0475_ID000120_it_5_tsl_100.npy
# Loading cached data from run0478_ID000180_it_5_tsl_100.npy
# Loading cached data from run0478_ID000222_it_5_tsl_100.npy
# Loading cached data from run0478_ID000299_it_5_tsl_100.npy
# Loading cached data from run0481_ID000069_it_5_tsl_100.npy
# Loading cached data from run0481_ID000384_it_5_tsl_100.npy
# Loading cached data from run0484_ID000321_it_5_tsl_100.npy
# Loading cached data from run0486_ID000108_it_5_tsl_100.npy
# Loading cached data from run0487_ID000320_it_5_tsl_100.npy
# Loading cached data from run0489_ID000040_it_5_tsl_100.npy
# Loading cached data from run0489_ID000339_it_5_tsl_100.npy
# Loading cached data from run0489_ID000353_it_5_tsl_100.npy
# Loading cached data from run0491_ID000173_it_5_tsl_100.npy
# Loading cached data from run0492_ID000231_it_5_tsl_100.npy
# Loading cached data from run0493_ID000305_it_5_tsl_100.npy
# Loading cached data from run0494_ID000343_it_5_tsl_100.npy
# Loading cached data from run0496_ID000386_it_5_tsl_100.npy
# Loading cached data from run0498_ID000059_it_5_tsl_100.npy
# Loading cached data from run0498_ID000071_it_5_tsl_100.npy
# Loading cached data from run0498_ID000168_it_5_tsl_100.npy
# Loading cached data from run0498_ID000373_it_5_tsl_100.npy
# Loading cached data from run0501_ID000313_it_5_tsl_100.npy
# Loading cached data from run0501_ID000398_it_5_tsl_100.npy
# Loading cached data from run0503_ID000143_it_5_tsl_100.npy
# Loading cached data from run0508_ID000316_it_5_tsl_100.npy
# Loading cached data from run0509_ID000243_it_5_tsl_100.npy
# Loading cached data from run0512_ID000238_it_5_tsl_100.npy
# Loading cached data from run0516_ID000336_it_5_tsl_100.npy
# Loading cached data from run0522_ID000294_it_5_tsl_100.npy
# Loading cached data from run0524_ID000087_it_5_tsl_100.npy
# Loading cached data from run0524_ID000291_it_5_tsl_100.npy
# Loading cached data from run0529_ID000420_it_5_tsl_100.npy
# Loading cached data from run0533_ID000144_it_5_tsl_100.npy
# Loading cached data from run0533_ID000171_it_5_tsl_100.npy
# Loading cached data from run0535_ID000141_it_5_tsl_100.npy
# Loading cached data from run0535_ID000181_it_5_tsl_100.npy
# Loading cached data from run0537_ID000149_it_5_tsl_100.npy
# Loading cached data from run0543_ID000437_it_5_tsl_100.npy
# Loading cached data from run0546_ID000406_it_5_tsl_100.npy
# Loading cached data from run0550_ID000253_it_5_tsl_100.npy
# Loading cached data from run0550_ID000494_it_5_tsl_100.npy
# Loading cached data from run0551_ID000099_it_5_tsl_100.npy
# Loading cached data from run0551_ID000150_it_5_tsl_100.npy
# Loading cached data from run0556_ID000312_it_5_tsl_100.npy
# Loading cached data from run0557_ID000319_it_5_tsl_100.npy
# Loading cached data from run0558_ID000096_it_5_tsl_100.npy
# Loading cached data from run0559_ID000332_it_5_tsl_100.npy
# Loading cached data from run0562_ID000069_it_5_tsl_100.npy
# Loading cached data from run0563_ID000044_it_5_tsl_100.npy
# Loading cached data from run0564_ID000354_it_5_tsl_100.npy
# Loading cached data from run0569_ID000136_it_5_tsl_100.npy
# Loading cached data from run0576_ID000397_it_5_tsl_100.npy
# Loading cached data from run0577_ID000106_it_5_tsl_100.npy
# Loading cached data from run0583_ID000329_it_5_tsl_100.npy
# Loading cached data from run0584_ID000213_it_5_tsl_100.npy
# Loading cached data from run0586_ID000161_it_5_tsl_100.npy
# Loading cached data from run0592_ID000035_it_5_tsl_100.npy
# Loading cached data from run0593_ID000019_it_5_tsl_100.npy
# Loading cached data from run0598_ID000199_it_5_tsl_100.npy
# Loading cached data from run0603_ID000005_it_5_tsl_100.npy
# Loading cached data from run0603_ID000195_it_5_tsl_100.npy
# Loading cached data from run0606_ID000304_it_5_tsl_100.npy
# Loading cached data from run0607_ID000306_it_5_tsl_100.npy
# Loading cached data from run0608_ID000286_it_5_tsl_100.npy
# Loading cached data from run0610_ID000063_it_5_tsl_100.npy
# Loading cached data from run0610_ID000260_it_5_tsl_100.npy
# Loading cached data from run0613_ID000309_it_5_tsl_100.npy
# Loading cached data from run0613_ID000375_it_5_tsl_100.npy
# Loading cached data from run0615_ID000207_it_5_tsl_100.npy
# Loading cached data from run0615_ID000245_it_5_tsl_100.npy
# Loading cached data from run0617_ID000297_it_5_tsl_100.npy
# Loading cached data from run0619_ID000308_it_5_tsl_100.npy
# Loading cached data from run0620_ID000109_it_5_tsl_100.npy
# Loading cached data from run0627_ID000386_it_5_tsl_100.npy
# Loading cached data from run0629_ID000087_it_5_tsl_100.npy
# Loading cached data from run0629_ID000224_it_5_tsl_100.npy
# Loading cached data from run0635_ID000075_it_5_tsl_100.npy
# Loading cached data from run0637_ID000089_it_5_tsl_100.npy
# Loading cached data from run0641_ID000127_it_5_tsl_100.npy
# Loading cached data from run0641_ID000226_it_5_tsl_100.npy
# Loading cached data from run0642_ID000033_it_5_tsl_100.npy
# Loading cached data from run0642_ID000185_it_5_tsl_100.npy
# Loading cached data from run0642_ID000462_it_5_tsl_100.npy
# Loading cached data from run0647_ID000398_it_5_tsl_100.npy
# Loading cached data from run0652_ID000307_it_5_tsl_100.npy
# Loading cached data from run0653_ID000037_it_5_tsl_100.npy
# Loading cached data from run0653_ID000078_it_5_tsl_100.npy
# Loading cached data from run0655_ID000259_it_5_tsl_100.npy
# Loading cached data from run0658_ID000054_it_5_tsl_100.npy
# Loading cached data from run0658_ID000260_it_5_tsl_100.npy
# Loading cached data from run0664_ID000064_it_5_tsl_100.npy
# Loading cached data from run0664_ID000350_it_5_tsl_100.npy
# Loading cached data from run0667_ID000126_it_5_tsl_100.npy
# Loading cached data from run0667_ID000302_it_5_tsl_100.npy
# Loading cached data from run0668_ID000294_it_5_tsl_100.npy
# Loading cached data from run0672_ID000265_it_5_tsl_100.npy
# Loading cached data from run0677_ID000457_it_5_tsl_100.npy
# Loading cached data from run0684_ID000011_it_5_tsl_100.npy
# Loading cached data from run0684_ID000346_it_5_tsl_100.npy
# Loading cached data from run0687_ID000058_it_5_tsl_100.npy
# Loading cached data from run0688_ID000044_it_5_tsl_100.npy
# Loading cached data from run0688_ID000432_it_5_tsl_100.npy
# Loading cached data from run0689_ID000454_it_5_tsl_100.npy
# Loading cached data from run0689_ID000513_it_5_tsl_100.npy
# Loading cached data from run0697_ID000167_it_5_tsl_100.npy
# Loading cached data from run0700_ID000206_it_5_tsl_100.npy
# Loading cached data from run0709_ID000364_it_5_tsl_100.npy
# Loading cached data from run0710_ID000198_it_5_tsl_100.npy
# Loading cached data from run0711_ID000203_it_5_tsl_100.npy
# Loading cached data from run0712_ID000163_it_5_tsl_100.npy
# Loading cached data from run0719_ID000018_it_5_tsl_100.npy
# Loading cached data from run0720_ID000203_it_5_tsl_100.npy
# Loading cached data from run0722_ID000130_it_5_tsl_100.npy
# Loading cached data from run0722_ID000187_it_5_tsl_100.npy
# Loading cached data from run0729_ID000124_it_5_tsl_100.npy
# Loading cached data from run0731_ID000202_it_5_tsl_100.npy
# Loading cached data from run0734_ID000309_it_5_tsl_100.npy
# Loading cached data from run0735_ID000071_it_5_tsl_100.npy
# Loading cached data from run0762_ID000202_it_5_tsl_100.npy
# Loading cached data from run0763_ID000224_it_5_tsl_100.npy
# Loading cached data from run0765_ID000033_it_5_tsl_100.npy
# Loading cached data from run0766_ID000057_it_5_tsl_100.npy
# Loading cached data from run0767_ID000231_it_5_tsl_100.npy
# Loading cached data from run0780_ID000007_it_5_tsl_100.npy
# Loading cached data from run0782_ID000343_it_5_tsl_100.npy
# Loading cached data from run0785_ID000315_it_5_tsl_100.npy
# Loading cached data from run0787_ID000040_it_5_tsl_100.npy
# Loading cached data from run0788_ID000236_it_5_tsl_100.npy
# Loading cached data from run0792_ID000290_it_5_tsl_100.npy
# Loading cached data from run0793_ID000454_it_5_tsl_100.npy
# Loading cached data from run0793_ID000465_it_5_tsl_100.npy
# Loading cached data from run0798_ID000122_it_5_tsl_100.npy
# Loading cached data from run0798_ID000403_it_5_tsl_100.npy
# Loading cached data from run0798_ID000437_it_5_tsl_100.npy
# Loading cached data from run0799_ID000140_it_5_tsl_100.npy
# Loading cached data from run0804_ID000031_it_5_tsl_100.npy
# Loading cached data from run0804_ID000264_it_5_tsl_100.npy
# Loading cached data from run0808_ID000191_it_5_tsl_100.npy
# Loading cached data from run0811_ID000253_it_5_tsl_100.npy
# Loading cached data from run0812_ID000337_it_5_tsl_100.npy
# Loading cached data from run0813_ID000124_it_5_tsl_100.npy
# Loading cached data from run0822_ID000056_it_5_tsl_100.npy
# Loading cached data from run0836_ID000198_it_5_tsl_100.npy
# Loading cached data from run0836_ID000340_it_5_tsl_100.npy
# Loading cached data from run0837_ID000263_it_5_tsl_100.npy
# Loading cached data from run0839_ID000040_it_5_tsl_100.npy
# Loading cached data from run0842_ID000055_it_5_tsl_100.npy
# Loading cached data from run0842_ID000212_it_5_tsl_100.npy
# Loading cached data from run0842_ID000312_it_5_tsl_100.npy
# Loading cached data from run0853_ID000363_it_5_tsl_100.npy
# Loading cached data from run0865_ID000336_it_5_tsl_100.npy
# Loading cached data from run0869_ID000370_it_5_tsl_100.npy
# Loading cached data from run0877_ID000060_it_5_tsl_100.npy
# Loading cached data from run0877_ID000233_it_5_tsl_100.npy
# Loading cached data from run0879_ID000213_it_5_tsl_100.npy
# Loading cached data from run0880_ID000380_it_5_tsl_100.npy
# Loading cached data from run0881_ID000086_it_5_tsl_100.npy
# Loading cached data from run0885_ID000163_it_5_tsl_100.npy
# Loading cached data from run0889_ID000211_it_5_tsl_100.npy
# Loading cached data from run0889_ID000364_it_5_tsl_100.npy
# [2022-12-22 16:32:37.894628] Loaded data from logs/check_recostructions_for_templates_out/data_cache. Templates: dict_keys(['run0002_ID000044', 'run0005_ID000225', 'run0009_ID000191', 'run0011_ID000139', 'run0013_ID000321', 'run0016_ID000340', 'run0017_ID000132', 'run0017_ID000261', 'run0017_ID000302', 'run0019_ID000070', 'run0019_ID000268', 'run0019_ID000338', 'run0021_ID000373', 'run0023_ID000267', 'run0025_ID000471', 'run0026_ID000127', 'run0027_ID000288', 'run0029_ID000397', 'run0029_ID000446', 'run0032_ID000190', 'run0036_ID000168', 'run0037_ID000283', 'run0038_ID000228', 'run0039_ID000031', 'run0043_ID000231', 'run0043_ID000324', 'run0043_ID000460', 'run0045_ID000095', 'run0046_ID000029', 'run0046_ID000300', 'run0048_ID000219', 'run0048_ID000465', 'run0050_ID000319', 'run0051_ID000166', 'run0051_ID000434', 'run0053_ID000030', 'run0055_ID000128', 'run0058_ID000423', 'run0066_ID000041', 'run0066_ID000123', 'run0067_ID000038', 'run0067_ID000395', 'run0074_ID000249', 'run0076_ID000465', 'run0077_ID000381', 'run0079_ID000181', 'run0079_ID000383', 'run0080_ID000283', 'run0087_ID000156', 'run0091_ID000232', 'run0096_ID000038', 'run0099_ID000496', 'run0101_ID000172', 'run0103_ID000247', 'run0106_ID000232', 'run0108_ID000020', 'run0109_ID000136', 'run0111_ID000027', 'run0111_ID000118', 'run0113_ID000112', 'run0114_ID000299', 'run0115_ID000189', 'run0117_ID000327', 'run0118_ID000382', 'run0118_ID000393', 'run0121_ID000156', 'run0121_ID000209', 'run0122_ID000021', 'run0124_ID000071', 'run0125_ID000077', 'run0126_ID000344', 'run0130_ID000461', 'run0131_ID000391', 'run0132_ID000380', 'run0138_ID000218', 'run0142_ID000123', 'run0146_ID000301', 'run0147_ID000002', 'run0150_ID000189', 'run0151_ID000312', 'run0154_ID000068', 'run0155_ID000328', 'run0156_ID000028', 'run0157_ID000407', 'run0158_ID000220', 'run0158_ID000313', 'run0158_ID000359', 'run0159_ID000035', 'run0160_ID000149', 'run0162_ID000268', 'run0163_ID000414', 'run0167_ID000041', 'run0170_ID000124', 'run0170_ID000218', 'run0170_ID000400', 'run0170_ID000418', 'run0173_ID000131', 'run0175_ID000139', 'run0175_ID000300', 'run0176_ID000218', 'run0176_ID000272', 'run0176_ID000473', 'run0177_ID000070', 'run0180_ID000255', 'run0181_ID000296', 'run0182_ID000054', 'run0183_ID000331', 'run0187_ID000435', 'run0189_ID000293', 'run0191_ID000005', 'run0191_ID000229', 'run0192_ID000017', 'run0192_ID000068', 'run0193_ID000013', 'run0193_ID000134', 'run0195_ID000111', 'run0197_ID000145', 'run0199_ID000215', 'run0199_ID000278', 'run0202_ID000245', 'run0204_ID000284', 'run0207_ID000154', 'run0209_ID000300', 'run0210_ID000016', 'run0210_ID000040', 'run0210_ID000082', 'run0210_ID000221', 'run0211_ID000312', 'run0211_ID000462', 'run0214_ID000101', 'run0216_ID000185', 'run0216_ID000333', 'run0218_ID000245', 'run0219_ID000029', 'run0221_ID000122', 'run0221_ID000373', 'run0222_ID000126', 'run0222_ID000318', 'run0226_ID000257', 'run0226_ID000442', 'run0228_ID000404', 'run0231_ID000152', 'run0231_ID000320', 'run0233_ID000376', 'run0236_ID000181', 'run0240_ID000371', 'run0240_ID000477', 'run0242_ID000066', 'run0242_ID000208', 'run0245_ID000236', 'run0250_ID000440', 'run0251_ID000377', 'run0252_ID000066', 'run0254_ID000090', 'run0254_ID000456', 'run0254_ID000470', 'run0256_ID000112', 'run0258_ID000139', 'run0258_ID000165', 'run0263_ID000260', 'run0266_ID000397', 'run0270_ID000260', 'run0270_ID000262', 'run0271_ID000336', 'run0276_ID000003', 'run0276_ID000042', 'run0278_ID000111', 'run0278_ID000152', 'run0279_ID000405', 'run0280_ID000101', 'run0283_ID000065', 'run0284_ID000362', 'run0285_ID000014', 'run0286_ID000021', 'run0286_ID000099', 'run0286_ID000206', 'run0290_ID000056', 'run0291_ID000001', 'run0291_ID000193', 'run0292_ID000156', 'run0294_ID000203', 'run0298_ID000339', 'run0301_ID000376', 'run0302_ID000382', 'run0309_ID000061', 'run0314_ID000223', 'run0315_ID000129', 'run0317_ID000219', 'run0318_ID000143', 'run0321_ID000159', 'run0323_ID000052', 'run0325_ID000165', 'run0339_ID000132', 'run0339_ID00024 ...

# %% [markdown]
# ## Plot some samples

# %%
#for template in list(data_manager.data.keys())[0:5]:
#    data_manager.plot_timeseries(template, data_manager.data[template], 1, sim_params, output_dir, labels=features_names)

# %% [markdown]
# # TESTING

# %%
data_manager.load_scaler(model_config_rnn.scaler_path) # model_config_rnn.scaler_path or model_config_cnn.scaler_path

# %%
test_all_x, test_all_y = data_manager.get_test_set_all_templates(verbose=False, onset=250, integration_time=integration_time, sub_window_size=5, stride=1)

# %% [markdown]
# # RNN

# %% [markdown]
# ## Standard metrics - 3 sigma threshold

# %%
model_config_rnn.pvalue_table

# %%
SIGMA_THRESHOLD = 3

# %%
sigma_threshold = get_threshold_for_sigma(model_config_rnn.pvalue_table, SIGMA_THRESHOLD)
model_config_rnn.ad.threshold = sigma_threshold
print(f"Threshold: {model_config_rnn.ad.threshold} corresponding to {get_sigma_from_ts(model_config_rnn.pvalue_table, model_config_rnn.ad.threshold)} sigma")

# %%
#print(f"************** Evaluating {model_config_rnn.name} patience={model_config_rnn.patience} **************")
#metrics = model_config_rnn.ad.evaluate(test_all_x, test_all_y)
#for k,v in metrics.items():
#    print(k,v)
#print("detection_delay:",model_config_rnn.ad.detection_delay(test_all_y, model_config_rnn.ad.predict(test_all_x), test_set_size, model_config_rnn.timesteps)#)

# %% [markdown]
# ## Standard metrics - 5 sigma threshold

# %%
from rtapipe.lib.plotting.PlotConfig import PlotConfig

pc = PlotConfig()

# %%
(pc.fig_size[0]*2,pc.fig_size[1]*2)

# %%
SIGMA_THRESHOLD = 5

# %%
sigma_threshold = get_threshold_for_sigma(model_config_rnn.pvalue_table, SIGMA_THRESHOLD)
model_config_rnn.ad.threshold = sigma_threshold
print(f"Threshold: {model_config_rnn.ad.threshold} corresponding to {get_sigma_from_ts(model_config_rnn.pvalue_table, model_config_rnn.ad.threshold)} sigma")

# %%
# %matplotlib inline

def plot_predictions2(samples, samplesLabels, c_threshold, recostructions, mse_per_sample, mse_per_sample_features, features_names=[], integration_time=5, epoch="", max_plots=5, showFig=False, saveFig=True, outputDir="./", figName="predictions.png"):

    pc = PlotConfig()

    total_samples = samples.shape[0]
    
    max_samples = 5
    n_features = samples.shape[2]
    if len(features_names) != n_features:
        features_names = [f"Feature {i}" for i in range(n_features)]

    num_plots = total_samples // max_samples

    mask = (mse_per_sample > c_threshold)

    start = 0
    for p in tqdm(range(num_plots)):

        if p == max_plots:
            print("Max plots reached")
            break



                
        annotations = [f"{i*integration_time}-{i*integration_time+samples.shape[1]}" for i in range(0,96)]
        xticks = [i for i in range(0,96)]

        current_samples = samples[start:start+max_samples, :, :]
        current_samplesLabels = samplesLabels[start:start+max_samples]
        current_samples_annotations = annotations[start:start+max_samples]
        current_samples_xticks = xticks[start:start+max_samples]
        current_recostructions = recostructions[start:start+max_samples, :, :]
        current_mask = mask[start:start+max_samples]
        current_mse_per_sample_features = mse_per_sample_features[start:start+max_samples]
        current_mse_per_sample = mse_per_sample[start:start+max_samples]

        #print("current_samples:",current_samples)
        #print("current_mse_per_sample_features: ", current_mse_per_sample_features)
        start += max_samples

        ymax, ymin = 1, 0
        
        #print(f"Plot {p}. \nNumber of predictions: {len(current_samples)}. \nSample shape: {current_samples.shape} \n Number of features: {n_features}")

        real_labels = ["grb" if lab==1 else "bkg" for lab in current_samplesLabels ]
        pred_labels = ["grb" if lab==1 else "bkg" for lab in current_mask          ]

        fig, ax = plt.subplots(n_features, max_samples, figsize=(pc.fig_size[0]*2,pc.fig_size[1]*2))
        fig.suptitle(f"5σ threshold={round(c_threshold, 3)}")
        #fig.suptitle(f"Predictions (using threshold={round(c_threshold, 3)})")
        fig.supylabel('Energy bins (TeV)')

      

        # For each feature..
        for f in range(n_features):

            for i in range(max_samples):

                # Get a sample and its recostruction
                sample = current_samples[i][:,f]
                recoSample = current_recostructions[i][:,f]

                # And plot them                
                ax[f, i].plot(recoSample, color='red',  marker='o', markersize=6, linestyle='dashed', label="reconstruction")
                ax[f, i].plot(sample,     color="blue", marker='o', markersize=6, linestyle='dashed', label="ground truth")
                ax[f, i].set_ylim(ymin, ymax)

                
                ax[f, i].set_xticks(current_samples_xticks, current_samples_annotations, fontsize=10)

                if real_labels[i] != pred_labels[i]:
                    ax[f, i].set_facecolor('#e6e6e6')

                # Only the first column will show the Y labels
                if i == 0:
                    ax[f, i].set_ylabel(features_names[f].split("EB_")[1].split(" TeV")[0])


                ax[f, i].set_xlabel("mse={:.6f}".format(current_mse_per_sample_features[i, f]))

                # Only the first row will show the TN/FP/FN/TP labels and the averaged mse
                if f == 0:
                    title = "Sample {}\nW. avg mse={:.3f}\nClassification=".format(start+i-max_samples, current_mse_per_sample[i])
                    if real_labels[i] == "grb" and real_labels[i] == pred_labels[i]:
                        title += "TP"
                    elif real_labels[i] == "grb" and real_labels[i] != pred_labels[i]:
                        title += "FN"
                    elif real_labels[i] == "bkg" and real_labels[i] == pred_labels[i]:  
                        title += "TN"
                    elif real_labels[i] == "bkg" and real_labels[i] != pred_labels[i]:
                        title += "FP"
                    ax[f, i].set_title(title)

        handles, labels = ax[f, i].get_legend_handles_labels()
        fig.legend(handles, labels, loc='upper left')

        plt.tight_layout()

        if showFig:
            plt.show()

        if saveFig:
            Path(outputDir).mkdir(parents=True, exist_ok=True)
            outputPath = Path(outputDir).joinpath(f"{figName}_epoch_{epoch}_plot_{p}.png")
            fig.savefig(outputPath, dpi=200)

        plt.close()

# %%
outputDir = Path(output_dir).joinpath("predictions")
outputDir.mkdir(exist_ok=True)

# %%
metrics = model_config_rnn.ad.evaluate(test_all_x, test_all_y)

# %%
showFig = True
saveFig = True 
plot_predictions2(test_all_x, test_all_y, model_config_rnn.ad.threshold, model_config_rnn.ad.reconstruct(test_all_x), model_config_rnn.ad.loss_f.mse_per_sample.numpy(), model_config_rnn.ad.loss_f.mse_per_sample_features.numpy(), features_names=features_names, epoch=model_config_rnn.epoch, max_plots=999, showFig=showFig, saveFig=saveFig, outputDir=outputDir, figName=f"{model_config_rnn.name}_patience_{model_config_rnn.patience}")
